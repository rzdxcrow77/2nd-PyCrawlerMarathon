# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11768333532","type":"CreateEvent","actor":{"id":49699333,"login":"dependabot[bot]","display_login":"dependabot","gravatar_id":"","url":"https://api.github.com/users/dependabot[bot]","avatar_url":"https://avatars.githubusercontent.com/u/49699333?"},"repo":{"id":170465892,"name":"axlwang1976/js-underground","url":"https://api.github.com/repos/axlwang1976/js-underground"},"payload":{"ref":"dependabot/npm_and_yarn/acorn-5.7.4","ref_type":"branch","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2020-03-15T09:47:58Z"},{"id":"11768333530","type":"ForkEvent","actor":{"id":7135061,"login":"k-tomak","display_login":"k-tomak","gravatar_id":"","url":"https://api.github.com/users/k-tomak","avatar_url":"https://avatars.githubusercontent.com/u/7135061?"},"repo":{"id":291137,"name":"ohmyzsh/ohmyzsh","url":"https://api.github.com/repos/ohmyzsh/ohmyzsh"},"payload":{"forkee":{"id":247438795,"node_id":"MDEwOlJlcG9zaXRvcnkyNDc0Mzg3OTU=","name":"ohmyzsh","full_name":"k-tomak/ohmyzsh","private":false,"owner":{"login":"k-tomak","id":7135061,"node_id":"MDQ6VXNlcjcxMzUwNjE=","avatar_url":"https://avatars2.githubusercontent.com/u/7135061?v=4","gravatar_id":"","url":"https://api.github.com/users/k-tomak","html_url":"https://github.com/k-tomak","followers_url":"https://api.github.com/users/k-tomak/followers","following_url":"https://api.github.com/users/k-tomak/following{/other_user}","gists_url":"https://api.github.com/users/k-tomak/gists{/gist_id}","starred_url":"https://api.github.com/users/k-tomak/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/k-tomak/subscriptions","organizations_url":"https://api.github.com/users/k-tomak/orgs","repos_url":"https://api.github.com/users/k-tomak/repos","events_url":"https://api.github.com/users/k-tomak/events{/privacy}","received_events_url":"https://api.github.com/users/k-tomak/received_events","type":"User","site_admin":false},"html_url":"https://github.com/k-tomak/ohmyzsh","description":"🙃 A delightful community-driven (with 1500+ contributors) framework for managing your zsh configuration. Includes 200+ optional plugins (rails, git, OSX, hub, capistrano, brew, ant, php, python, etc), over 140 themes to spice up your morning, and an auto-update tool so that makes it easy to keep up with the latest updates from the community.","fork":true,"url":"https://api.github.com/repos/k-tomak/ohmyzsh","forks_url":"https://api.github.com/repos/k-tomak/ohmyzsh/forks","keys_url":"https://api.github.com/repos/k-tomak/ohmyzsh/keys{/key_id}","collaborators_url":"https://api.github.com/repos/k-tomak/ohmyzsh/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/k-tomak/ohmyzsh/teams","hooks_url":"https://api.github.com/repos/k-tomak/ohmyzsh/hooks","issue_events_url":"https://api.github.com/repos/k-tomak/ohmyzsh/issues/events{/number}","events_url":"https://api.github.com/repos/k-tomak/ohmyzsh/events","assignees_url":"https://api.github.com/repos/k-tomak/ohmyzsh/assignees{/user}","branches_url":"https://api.github.com/repos/k-tomak/ohmyzsh/branches{/branch}","tags_url":"https://api.github.com/repos/k-tomak/ohmyzsh/tags","blobs_url":"https://api.github.com/repos/k-tomak/ohmyzsh/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/k-tomak/ohmyzsh/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/k-tomak/ohmyzsh/git/refs{/sha}","trees_url":"https://api.github.com/repos/k-tomak/ohmyzsh/git/trees{/sha}","statuses_url":"https://api.github.com/repos/k-tomak/ohmyzsh/statuses/{sha}","languages_url":"https://api.github.com/repos/k-tomak/ohmyzsh/languages","stargazers_url":"https://api.github.com/repos/k-tomak/ohmyzsh/stargazers","contributors_url":"https://api.github.com/repos/k-tomak/ohmyzsh/contributors","subscribers_url":"https://api.github.com/repos/k-tomak/ohmyzsh/subscribers","subscription_url":"https://api.github.com/repos/k-tomak/ohmyzsh/subscription","commits_url":"https://api.github.com/repos/k-tomak/ohmyzsh/commits{/s ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '11768333532',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 170465892,
#    'name': 'axlwang1976/js-underground',
#    'url': 'https://api.github.com/repos/axlwang1976/js-underground'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/acorn-5.7.4',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-15T09:47:58Z'},
#  {'id': '11768333530',
#   'type': 'ForkEvent',
#   'actor': {'id': 7135061,
#    'login': 'k-tomak',
#    'display_login': 'k-tomak',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/k-tomak',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7135061?'},
#   'repo': {'id': 291137,
#    'name': 'ohmyzsh/ohmyzsh',
#    'url': 'https://api.github.com/repos/ohmyzsh/ohmyzsh'},
#   'payload': {'forkee': {'id': 247438795,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyNDc0Mzg3OTU=',
#     'name': 'ohmyzsh',
#     'full_name': 'k-tomak/ohmyzsh',
#     'private': False,
#     'owner': {'login': 'k-tomak',
#      'id': 7135061,
#      'node_id': 'MDQ6VXNlcjcxMzUwNjE=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/7135061?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/k-tomak',
#      'html_url': 'https://github.com/k-tomak',
#      'followers_url': 'https://api.github.com/users/k-tomak/followers',
#      'following_url': 'https://api.github.com/users/k-tomak/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/k-tomak/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/k-tomak/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/k-tomak/subscriptions',
#      'organizations_url': 'https://api.github.com/users/k-tomak/orgs',
#      'repos_url': 'https://api.github.com/users/k-tomak/repos',
#      'events_url': 'https://api.github.com/users/k-tomak/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/k-tomak/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/k-tomak/ohmyzsh',
#     'description': '🙃 A delightful community-driven (with 1500+ contributors) framework for managing your zsh configuration. Includes 200+ optional plugins (rails, git, OSX, hub, capistrano, brew, ant, php, python, etc), over 140 themes to spice up your morning, and an auto-update tool so that makes it easy to keep up with the latest updates from the community.',
#     'fork': True,
#     'url': 'https://api.github.com/repos/k-tomak/ohmyzsh',
#     'forks_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/forks',
#     'keys_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/teams',
#     'hooks_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/hooks',
#     'issue_events_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/events',
#     'assignees_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/tags',
#     'blobs_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/languages',
#     'stargazers_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/stargazers',
#     'contributors_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/contributors',
#     'subscribers_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/subscribers',
#     'subscription_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/subscription',
#     'commits_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/merges',
#     'archive_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/downloads',
#     'issues_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/k-tomak/ohmyzsh/deployments',
#     'created_at': '2020-03-15T09:47:58Z',
#     'updated_at': '2020-03-15T09:32:42Z',
#     'pushed_at': '2020-03-12T21:36:42Z',
#     'git_url': 'git://github.com/k-tomak/ohmyzsh.git',
#     'ssh_url': 'git@github.com:k-tomak/ohmyzsh.git',
#     'clone_url': 'https://github.com/k-tomak/ohmyzsh.git',
#     'svn_url': 'https://github.com/k-tomak/ohmyzsh',
#     'homepage': 'https://ohmyz.sh/',
#     'size': 6533,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2020-03-15T09:47:58Z',
#   'org': {'id': 22552083,
#    'login': 'ohmyzsh',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ohmyzsh',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22552083?'}},
#  {'id': '11768333525',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 39814207,
#    'login': 'pull[bot]',
#    'display_login': 'pull',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pull[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39814207?'},
#   'repo': {'id': 247261872,
#    'name': 'zys-contribs/Front-End-Interview-Notebook',
#    'url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook'},
#   'payload': {'action': 'closed',
#    'number': 1,
#    'pull_request': {'url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/pulls/1',
#     'id': 388644448,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0Mzg4NjQ0NDQ4',
#     'html_url': 'https://github.com/zys-contribs/Front-End-Interview-Notebook/pull/1',
#     'diff_url': 'https://github.com/zys-contribs/Front-End-Interview-Notebook/pull/1.diff',
#     'patch_url': 'https://github.com/zys-contribs/Front-End-Interview-Notebook/pull/1.patch',
#     'issue_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/issues/1',
#     'number': 1,
#     'state': 'closed',
#     'locked': False,
#     'title': '[pull] master from CavsZhouyou:master',
#     'user': {'login': 'pull[bot]',
#      'id': 39814207,
#      'node_id': 'MDM6Qm90Mzk4MTQyMDc=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/12910?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pull%5Bbot%5D',
#      'html_url': 'https://github.com/apps/pull',
#      'followers_url': 'https://api.github.com/users/pull%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/pull%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pull%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pull%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pull%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pull%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/pull%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/pull%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pull%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'See [Commits](/zys-contribs/Front-End-Interview-Notebook/pull/1/commits) and [Changes](/zys-contribs/Front-End-Interview-Notebook/pull/1/files) for more details.\n\n-----\nCreated by [<img src="https://prod.download/pull-18h-svg" valign="bottom"/> **pull[bot]**](https://github.com/wei/pull). Want to support this open source service? [Please star it : )](https://github.com/wei/pull)',
#     'created_at': '2020-03-15T09:47:54Z',
#     'updated_at': '2020-03-15T09:47:58Z',
#     'closed_at': '2020-03-15T09:47:58Z',
#     'merged_at': '2020-03-15T09:47:58Z',
#     'merge_commit_sha': 'a32d575867c6bf53a3ba87aeeba25a9a83f01731',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 1910568187,
#       'node_id': 'MDU6TGFiZWwxOTEwNTY4MTg3',
#       'url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/labels/:arrow_heading_down:%20pull',
#       'name': ':arrow_heading_down: pull',
#       'color': 'ededed',
#       'default': False,
#       'description': None}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/pulls/1/commits',
#     'review_comments_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/pulls/1/comments',
#     'review_comment_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/issues/1/comments',
#     'statuses_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/statuses/a32d575867c6bf53a3ba87aeeba25a9a83f01731',
#     'head': {'label': 'CavsZhouyou:master',
#      'ref': 'master',
#      'sha': 'a32d575867c6bf53a3ba87aeeba25a9a83f01731',
#      'user': {'login': 'CavsZhouyou',
#       'id': 29836408,
#       'node_id': 'MDQ6VXNlcjI5ODM2NDA4',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/29836408?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/CavsZhouyou',
#       'html_url': 'https://github.com/CavsZhouyou',
#       'followers_url': 'https://api.github.com/users/CavsZhouyou/followers',
#       'following_url': 'https://api.github.com/users/CavsZhouyou/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/CavsZhouyou/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/CavsZhouyou/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/CavsZhouyou/subscriptions',
#       'organizations_url': 'https://api.github.com/users/CavsZhouyou/orgs',
#       'repos_url': 'https://api.github.com/users/CavsZhouyou/repos',
#       'events_url': 'https://api.github.com/users/CavsZhouyou/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/CavsZhouyou/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 163486975,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNjM0ODY5NzU=',
#       'name': 'Front-End-Interview-Notebook',
#       'full_name': 'CavsZhouyou/Front-End-Interview-Notebook',
#       'private': False,
#       'owner': {'login': 'CavsZhouyou',
#        'id': 29836408,
#        'node_id': 'MDQ6VXNlcjI5ODM2NDA4',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/29836408?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/CavsZhouyou',
#        'html_url': 'https://github.com/CavsZhouyou',
#        'followers_url': 'https://api.github.com/users/CavsZhouyou/followers',
#        'following_url': 'https://api.github.com/users/CavsZhouyou/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/CavsZhouyou/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/CavsZhouyou/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/CavsZhouyou/subscriptions',
#        'organizations_url': 'https://api.github.com/users/CavsZhouyou/orgs',
#        'repos_url': 'https://api.github.com/users/CavsZhouyou/repos',
#        'events_url': 'https://api.github.com/users/CavsZhouyou/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/CavsZhouyou/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/CavsZhouyou/Front-End-Interview-Notebook',
#       'description': ':ant:前端面试复习笔记',
#       'fork': False,
#       'url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook',
#       'forks_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/forks',
#       'keys_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/teams',
#       'hooks_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/hooks',
#       'issue_events_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/events',
#       'assignees_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/tags',
#       'blobs_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/languages',
#       'stargazers_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/stargazers',
#       'contributors_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/contributors',
#       'subscribers_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/subscribers',
#       'subscription_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/subscription',
#       'commits_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/merges',
#       'archive_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/downloads',
#       'issues_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/CavsZhouyou/Front-End-Interview-Notebook/deployments',
#       'created_at': '2018-12-29T07:16:19Z',
#       'updated_at': '2020-03-15T09:35:12Z',
#       'pushed_at': '2020-03-15T09:35:10Z',
#       'git_url': 'git://github.com/CavsZhouyou/Front-End-Interview-Notebook.git',
#       'ssh_url': 'git@github.com:CavsZhouyou/Front-End-Interview-Notebook.git',
#       'clone_url': 'https://github.com/CavsZhouyou/Front-End-Interview-Notebook.git',
#       'svn_url': 'https://github.com/CavsZhouyou/Front-End-Interview-Notebook',
#       'homepage': '',
#       'size': 584,
#       'stargazers_count': 456,
#       'watchers_count': 456,
#       'language': None,
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 101,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 101,
#       'open_issues': 1,
#       'watchers': 456,
#       'default_branch': 'master'}},
#     'base': {'label': 'zys-contribs:master',
#      'ref': 'master',
#      'sha': '327f4fe26244f18c2ef86097c95d72285617e0a5',
#      'user': {'login': 'zys-contribs',
#       'id': 42747121,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQyNzQ3MTIx',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/42747121?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/zys-contribs',
#       'html_url': 'https://github.com/zys-contribs',
#       'followers_url': 'https://api.github.com/users/zys-contribs/followers',
#       'following_url': 'https://api.github.com/users/zys-contribs/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/zys-contribs/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/zys-contribs/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/zys-contribs/subscriptions',
#       'organizations_url': 'https://api.github.com/users/zys-contribs/orgs',
#       'repos_url': 'https://api.github.com/users/zys-contribs/repos',
#       'events_url': 'https://api.github.com/users/zys-contribs/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/zys-contribs/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 247261872,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNDcyNjE4NzI=',
#       'name': 'Front-End-Interview-Notebook',
#       'full_name': 'zys-contribs/Front-End-Interview-Notebook',
#       'private': False,
#       'owner': {'login': 'zys-contribs',
#        'id': 42747121,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQyNzQ3MTIx',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/42747121?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/zys-contribs',
#        'html_url': 'https://github.com/zys-contribs',
#        'followers_url': 'https://api.github.com/users/zys-contribs/followers',
#        'following_url': 'https://api.github.com/users/zys-contribs/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/zys-contribs/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/zys-contribs/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/zys-contribs/subscriptions',
#        'organizations_url': 'https://api.github.com/users/zys-contribs/orgs',
#        'repos_url': 'https://api.github.com/users/zys-contribs/repos',
#        'events_url': 'https://api.github.com/users/zys-contribs/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/zys-contribs/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/zys-contribs/Front-End-Interview-Notebook',
#       'description': ':ant:前端面试复习笔记',
#       'fork': True,
#       'url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook',
#       'forks_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/forks',
#       'keys_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/teams',
#       'hooks_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/hooks',
#       'issue_events_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/events',
#       'assignees_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/tags',
#       'blobs_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/languages',
#       'stargazers_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/stargazers',
#       'contributors_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/contributors',
#       'subscribers_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/subscribers',
#       'subscription_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/subscription',
#       'commits_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/merges',
#       'archive_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/downloads',
#       'issues_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/deployments',
#       'created_at': '2020-03-14T11:15:26Z',
#       'updated_at': '2020-03-14T11:15:28Z',
#       'pushed_at': '2020-03-15T09:47:57Z',
#       'git_url': 'git://github.com/zys-contribs/Front-End-Interview-Notebook.git',
#       'ssh_url': 'git@github.com:zys-contribs/Front-End-Interview-Notebook.git',
#       'clone_url': 'https://github.com/zys-contribs/Front-End-Interview-Notebook.git',
#       'svn_url': 'https://github.com/zys-contribs/Front-End-Interview-Notebook',
#       'homepage': '',
#       'size': 584,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/pulls/1'},
#      'html': {'href': 'https://github.com/zys-contribs/Front-End-Interview-Notebook/pull/1'},
#      'issue': {'href': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/issues/1'},
#      'comments': {'href': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/issues/1/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/pulls/1/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/pulls/1/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/zys-contribs/Front-End-Interview-Notebook/statuses/a32d575867c6bf53a3ba87aeeba25a9a83f01731'}},
#     'author_association': 'NONE',
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'pull[bot]',
#      'id': 39814207,
#      'node_id': 'MDM6Qm90Mzk4MTQyMDc=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/12910?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pull%5Bbot%5D',
#      'html_url': 'https://github.com/apps/pull',
#      'followers_url': 'https://api.github.com/users/pull%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/pull%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pull%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pull%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pull%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pull%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/pull%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/pull%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pull%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 2,
#     'additions': 2277,
#     'deletions': 2219,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-03-15T09:47:58Z',
#   'org': {'id': 42747121,
#    'login': 'zys-contribs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/zys-contribs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42747121?'}},
#  {'id': '11768333526',
#   'type': 'CreateEvent',
#   'actor': {'id': 22809542,
#    'login': 'konstantinullrich',
#    'display_login': 'konstantinullrich',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/konstantinullrich',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22809542?'},
#   'repo': {'id': 247438794,
#    'name': 'konstantinullrich/EthereumStarNotary',
#    'url': 'https://api.github.com/repos/konstantinullrich/EthereumStarNotary'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'StarNotary is a ERC721-Token deployed on the Rinkeby Ethereum Test Network.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-15T09:47:58Z'},
#  {'id': '11768333519',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 194524289,
#    'name': 'SyedMaazHasan/Assignment2',
#    'url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2'},
#   'payload': {'action': 'opened',
#    'number': 3,
#    'pull_request': {'url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/pulls/3',
#     'id': 388644467,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0Mzg4NjQ0NDY3',
#     'html_url': 'https://github.com/SyedMaazHasan/Assignment2/pull/3',
#     'diff_url': 'https://github.com/SyedMaazHasan/Assignment2/pull/3.diff',
#     'patch_url': 'https://github.com/SyedMaazHasan/Assignment2/pull/3.patch',
#     'issue_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/issues/3',
#     'number': 3,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump acorn from 5.7.3 to 5.7.4 in /reactcodingchallenge',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [acorn](https://github.com/acornjs/acorn) from 5.7.3 to 5.7.4.\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/acornjs/acorn/commit/6370e90067552022710190319cbbbd8c43001957"><code>6370e90</code></a> Mark version 5.7.4</li>\n<li><a href="https://github.com/acornjs/acorn/commit/fbc15b1344f6dfb992f67b4bbf1357436247c8a0"><code>fbc15b1</code></a> More rigorously check surrogate pairs in regexp validator</li>\n<li>See full diff in <a href="https://github.com/acornjs/acorn/compare/5.7.3...5.7.4">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=acorn&package-manager=npm_and_yarn&previous-version=5.7.3&new-version=5.7.4)](https://help.github.com/articles/configuring-automated-security-fixes)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot use these labels` will set the current labels as the default for future PRs for this repo and language\n- `@dependabot use these reviewers` will set the current reviewers as the default for future PRs for this repo and language\n- `@dependabot use these assignees` will set the current assignees as the default for future PRs for this repo and language\n- `@dependabot use this milestone` will set the current milestone as the default for future PRs for this repo and language\n\nYou can disable automated security fix PRs for this repo from the [Security Alerts page](https://github.com/SyedMaazHasan/Assignment2/network/alerts).\n\n</details>',
#     'created_at': '2020-03-15T09:47:58Z',
#     'updated_at': '2020-03-15T09:47:58Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/pulls/3/commits',
#     'review_comments_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/pulls/3/comments',
#     'review_comment_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/issues/3/comments',
#     'statuses_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/statuses/781973ba8d77cb2bd6cff8cf7c9f6bcafe6ac57c',
#     'head': {'label': 'SyedMaazHasan:dependabot/npm_and_yarn/reactcodingchallenge/acorn-5.7.4',
#      'ref': 'dependabot/npm_and_yarn/reactcodingchallenge/acorn-5.7.4',
#      'sha': '781973ba8d77cb2bd6cff8cf7c9f6bcafe6ac57c',
#      'user': {'login': 'SyedMaazHasan',
#       'id': 49359456,
#       'node_id': 'MDQ6VXNlcjQ5MzU5NDU2',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/49359456?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/SyedMaazHasan',
#       'html_url': 'https://github.com/SyedMaazHasan',
#       'followers_url': 'https://api.github.com/users/SyedMaazHasan/followers',
#       'following_url': 'https://api.github.com/users/SyedMaazHasan/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/SyedMaazHasan/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/SyedMaazHasan/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/SyedMaazHasan/subscriptions',
#       'organizations_url': 'https://api.github.com/users/SyedMaazHasan/orgs',
#       'repos_url': 'https://api.github.com/users/SyedMaazHasan/repos',
#       'events_url': 'https://api.github.com/users/SyedMaazHasan/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/SyedMaazHasan/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 194524289,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxOTQ1MjQyODk=',
#       'name': 'Assignment2',
#       'full_name': 'SyedMaazHasan/Assignment2',
#       'private': False,
#       'owner': {'login': 'SyedMaazHasan',
#        'id': 49359456,
#        'node_id': 'MDQ6VXNlcjQ5MzU5NDU2',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/49359456?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/SyedMaazHasan',
#        'html_url': 'https://github.com/SyedMaazHasan',
#        'followers_url': 'https://api.github.com/users/SyedMaazHasan/followers',
#        'following_url': 'https://api.github.com/users/SyedMaazHasan/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/SyedMaazHasan/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/SyedMaazHasan/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/SyedMaazHasan/subscriptions',
#        'organizations_url': 'https://api.github.com/users/SyedMaazHasan/orgs',
#        'repos_url': 'https://api.github.com/users/SyedMaazHasan/repos',
#        'events_url': 'https://api.github.com/users/SyedMaazHasan/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/SyedMaazHasan/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/SyedMaazHasan/Assignment2',
#       'description': 'REACT FRONTEND CODING CHALLENGE This problem statement is to test the ability of the user to go through the basics of React frontend framework and build the below UX in the same',
#       'fork': False,
#       'url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2',
#       'forks_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/forks',
#       'keys_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/teams',
#       'hooks_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/hooks',
#       'issue_events_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/events',
#       'assignees_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/tags',
#       'blobs_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/languages',
#       'stargazers_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/stargazers',
#       'contributors_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/contributors',
#       'subscribers_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/subscribers',
#       'subscription_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/subscription',
#       'commits_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/merges',
#       'archive_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/downloads',
#       'issues_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/deployments',
#       'created_at': '2019-06-30T14:18:39Z',
#       'updated_at': '2019-06-30T14:23:16Z',
#       'pushed_at': '2020-03-15T09:47:57Z',
#       'git_url': 'git://github.com/SyedMaazHasan/Assignment2.git',
#       'ssh_url': 'git@github.com:SyedMaazHasan/Assignment2.git',
#       'clone_url': 'https://github.com/SyedMaazHasan/Assignment2.git',
#       'svn_url': 'https://github.com/SyedMaazHasan/Assignment2',
#       'homepage': None,
#       'size': 436,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 3,
#       'license': None,
#       'forks': 0,
#       'open_issues': 3,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'SyedMaazHasan:master',
#      'ref': 'master',
#      'sha': '0502ad28e35e3983e57150468b87daace5235e1e',
#      'user': {'login': 'SyedMaazHasan',
#       'id': 49359456,
#       'node_id': 'MDQ6VXNlcjQ5MzU5NDU2',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/49359456?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/SyedMaazHasan',
#       'html_url': 'https://github.com/SyedMaazHasan',
#       'followers_url': 'https://api.github.com/users/SyedMaazHasan/followers',
#       'following_url': 'https://api.github.com/users/SyedMaazHasan/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/SyedMaazHasan/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/SyedMaazHasan/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/SyedMaazHasan/subscriptions',
#       'organizations_url': 'https://api.github.com/users/SyedMaazHasan/orgs',
#       'repos_url': 'https://api.github.com/users/SyedMaazHasan/repos',
#       'events_url': 'https://api.github.com/users/SyedMaazHasan/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/SyedMaazHasan/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 194524289,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxOTQ1MjQyODk=',
#       'name': 'Assignment2',
#       'full_name': 'SyedMaazHasan/Assignment2',
#       'private': False,
#       'owner': {'login': 'SyedMaazHasan',
#        'id': 49359456,
#        'node_id': 'MDQ6VXNlcjQ5MzU5NDU2',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/49359456?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/SyedMaazHasan',
#        'html_url': 'https://github.com/SyedMaazHasan',
#        'followers_url': 'https://api.github.com/users/SyedMaazHasan/followers',
#        'following_url': 'https://api.github.com/users/SyedMaazHasan/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/SyedMaazHasan/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/SyedMaazHasan/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/SyedMaazHasan/subscriptions',
#        'organizations_url': 'https://api.github.com/users/SyedMaazHasan/orgs',
#        'repos_url': 'https://api.github.com/users/SyedMaazHasan/repos',
#        'events_url': 'https://api.github.com/users/SyedMaazHasan/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/SyedMaazHasan/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/SyedMaazHasan/Assignment2',
#       'description': 'REACT FRONTEND CODING CHALLENGE This problem statement is to test the ability of the user to go through the basics of React frontend framework and build the below UX in the same',
#       'fork': False,
#       'url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2',
#       'forks_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/forks',
#       'keys_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/teams',
#       'hooks_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/hooks',
#       'issue_events_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/events',
#       'assignees_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/tags',
#       'blobs_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/languages',
#       'stargazers_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/stargazers',
#       'contributors_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/contributors',
#       'subscribers_url': 'https://api.github.com/repos/SyedMaazHasan/Assignment2/subscribers',
# ...
#       'statuses_url': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/languages',
#       'stargazers_url': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/stargazers',
#       'contributors_url': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/contributors',
#       'subscribers_url': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/subscribers',
#       'subscription_url': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/subscription',
#       'commits_url': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/merges',
#       'archive_url': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/downloads',
#       'issues_url': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/deployments',
#       'created_at': '2018-11-30T19:28:05Z',
#       'updated_at': '2019-01-31T21:42:06Z',
#       'pushed_at': '2020-03-15T09:47:56Z',
#       'git_url': 'git://github.com/jhipster-latino/coverb-demo-react.git',
#       'ssh_url': 'git@github.com:jhipster-latino/coverb-demo-react.git',
#       'clone_url': 'https://github.com/jhipster-latino/coverb-demo-react.git',
#       'svn_url': 'https://github.com/jhipster-latino/coverb-demo-react',
#       'homepage': None,
#       'size': 2833,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Java',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 4,
#       'license': None,
#       'forks': 1,
#       'open_issues': 4,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/pulls/13'},
#      'html': {'href': 'https://github.com/jhipster-latino/coverb-demo-react/pull/13'},
#      'issue': {'href': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/issues/13'},
#      'comments': {'href': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/issues/13/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/pulls/13/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/pulls/13/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/jhipster-latino/coverb-demo-react/statuses/db20571960a9d542b57627609420b995f9d85d02'}},
#     'author_association': 'NONE',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 164,
#     'deletions': 166,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2020-03-15T09:47:57Z'},
#  {'id': '11768333467',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 194159620,
#    'name': 'riti-sharma/project-2',
#    'url': 'https://api.github.com/repos/riti-sharma/project-2'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/acorn-5.7.4',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-15T09:47:57Z'},
#  {'id': '11768333466',
#   'type': 'PushEvent',
#   'actor': {'id': 41463804,
#    'login': 'hlwer',
#    'display_login': 'hlwer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hlwer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41463804?'},
#   'repo': {'id': 245073896,
#    'name': 'hlwer/hlwer.github.io',
#    'url': 'https://api.github.com/repos/hlwer/hlwer.github.io'},
#   'payload': {'push_id': 4766979783,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '101ef6ecc37acd1f7e54154f6abf10413db7fc94',
#    'before': '2573811d1ef935518fe6eef131c9a372e6790c4b',
#    'commits': [{'sha': '101ef6ecc37acd1f7e54154f6abf10413db7fc94',
#      'author': {'email': 'ihlwer', 'name': 'hlwer'},
#      'message': 'update from gridea: 2020-03-15 17:47:45',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hlwer/hlwer.github.io/commits/101ef6ecc37acd1f7e54154f6abf10413db7fc94'}]},
#   'public': True,
#   'created_at': '2020-03-15T09:47:57Z'},
#  {'id': '11768333463',
#   'type': 'PushEvent',
#   'actor': {'id': 61843437,
#    'login': 'enricemcorro',
#    'display_login': 'enricemcorro',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/enricemcorro',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61843437?'},
#   'repo': {'id': 245396736,
#    'name': 'enricemcorro/enricemcorro',
#    'url': 'https://api.github.com/repos/enricemcorro/enricemcorro'},
#   'payload': {'push_id': 4766979780,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '0ea5ce8beb254ced74981ec858c637a14a296e9b',
#    'before': '7ff0f1f88a1e45c56df5aedf69f81120be8b0d79',
#    'commits': [{'sha': '0ea5ce8beb254ced74981ec858c637a14a296e9b',
#      'author': {'email': 'enricemcorro@gmail.com', 'name': 'enricemcorro'},
#      'message': 'penis^2',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/enricemcorro/enricemcorro/commits/0ea5ce8beb254ced74981ec858c637a14a296e9b'}]},
#   'public': True,
#   'created_at': '2020-03-15T09:47:57Z'},
#  {'id': '11768333464',
#   'type': 'IssuesEvent',
#   'actor': {'id': 62202252,
#    'login': 'chris0416',
#    'display_login': 'chris0416',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chris0416',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/62202252?'},
#   'repo': {'id': 238888297,
#    'name': 'coding-coworking-club/python-2020-spring',
#    'url': 'https://api.github.com/repos/coding-coworking-club/python-2020-spring'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/coding-coworking-club/python-2020-spring/issues/30',
#     'repository_url': 'https://api.github.com/repos/coding-coworking-club/python-2020-spring',
#     'labels_url': 'https://api.github.com/repos/coding-coworking-club/python-2020-spring/issues/30/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/coding-coworking-club/python-2020-spring/issues/30/comments',
#     'events_url': 'https://api.github.com/repos/coding-coworking-club/python-2020-spring/issues/30/events',
#     'html_url': 'https://github.com/coding-coworking-club/python-2020-spring/issues/30',
#     'id': 581602205,
#     'node_id': 'MDU6SXNzdWU1ODE2MDIyMDU=',
#     'number': 30,
#     'title': '[General] input函數問題',
#     'user': {'login': 'chris0416',
#      'id': 62202252,
#      'node_id': 'MDQ6VXNlcjYyMjAyMjUy',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/62202252?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/chris0416',
#      'html_url': 'https://github.com/chris0416',
#      'followers_url': 'https://api.github.com/users/chris0416/followers',
#      'following_url': 'https://api.github.com/users/chris0416/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/chris0416/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/chris0416/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/chris0416/subscriptions',
#      'organizations_url': 'https://api.github.com/users/chris0416/orgs',
#      'repos_url': 'https://api.github.com/users/chris0416/repos',
#      'events_url': 'https://api.github.com/users/chris0416/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/chris0416/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1832741530,
#       'node_id': 'MDU6TGFiZWwxODMyNzQxNTMw',
#       'url': 'https://api.github.com/repos/coding-coworking-club/python-2020-spring/labels/general',
#       'name': 'general',
#       'color': '008672',
#       'default': False,
#       'description': 'This issue is for a general problem'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': {'login': 'alexypdu',
#      'id': 28721952,
#      'node_id': 'MDQ6VXNlcjI4NzIxOTUy',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/28721952?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/alexypdu',
#      'html_url': 'https://github.com/alexypdu',
#      'followers_url': 'https://api.github.com/users/alexypdu/followers',
#      'following_url': 'https://api.github.com/users/alexypdu/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/alexypdu/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/alexypdu/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/alexypdu/subscriptions',
#      'organizations_url': 'https://api.github.com/users/alexypdu/orgs',
#      'repos_url': 'https://api.github.com/users/alexypdu/repos',
#      'events_url': 'https://api.github.com/users/alexypdu/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/alexypdu/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'Kevinweisl',
#       'id': 12825883,
#       'node_id': 'MDQ6VXNlcjEyODI1ODgz',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/12825883?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Kevinweisl',
#       'html_url': 'https://github.com/Kevinweisl',
#       'followers_url': 'https://api.github.com/users/Kevinweisl/followers',
#       'following_url': 'https://api.github.com/users/Kevinweisl/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Kevinweisl/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Kevinweisl/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Kevinweisl/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Kevinweisl/orgs',
#       'repos_url': 'https://api.github.com/users/Kevinweisl/repos',
#       'events_url': 'https://api.github.com/users/Kevinweisl/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Kevinweisl/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'sc090410',
#       'id': 28396675,
#       'node_id': 'MDQ6VXNlcjI4Mzk2Njc1',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/28396675?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/sc090410',
#       'html_url': 'https://github.com/sc090410',
#       'followers_url': 'https://api.github.com/users/sc090410/followers',
#       'following_url': 'https://api.github.com/users/sc090410/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/sc090410/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/sc090410/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/sc090410/subscriptions',
#       'organizations_url': 'https://api.github.com/users/sc090410/orgs',
#       'repos_url': 'https://api.github.com/users/sc090410/repos',
#       'events_url': 'https://api.github.com/users/sc090410/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/sc090410/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'alexypdu',
#       'id': 28721952,
#       'node_id': 'MDQ6VXNlcjI4NzIxOTUy',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/28721952?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/alexypdu',
#       'html_url': 'https://github.com/alexypdu',
#       'followers_url': 'https://api.github.com/users/alexypdu/followers',
#       'following_url': 'https://api.github.com/users/alexypdu/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/alexypdu/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/alexypdu/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/alexypdu/subscriptions',
#       'organizations_url': 'https://api.github.com/users/alexypdu/orgs',
#       'repos_url': 'https://api.github.com/users/alexypdu/repos',
#       'events_url': 'https://api.github.com/users/alexypdu/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/alexypdu/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'hyusterr',
#       'id': 52968111,
#       'node_id': 'MDQ6VXNlcjUyOTY4MTEx',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/52968111?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/hyusterr',
#       'html_url': 'https://github.com/hyusterr',
#       'followers_url': 'https://api.github.com/users/hyusterr/followers',
#       'following_url': 'https://api.github.com/users/hyusterr/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/hyusterr/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/hyusterr/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/hyusterr/subscriptions',
#       'organizations_url': 'https://api.github.com/users/hyusterr/orgs',
#       'repos_url': 'https://api.github.com/users/hyusterr/repos',
#       'events_url': 'https://api.github.com/users/hyusterr/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/hyusterr/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-03-15T09:47:57Z',
#     'updated_at': '2020-03-15T09:47:57Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': '## 提交連結\r\n\r\n<!--\r\n在批改系統上作答的同學請填寫提交連結，若無則請留空。\r\n-->\r\n\r\n## 程式碼\r\n\r\n<!--\r\n請填入你的程式碼並注意縮排。\r\n請勿上傳螢幕截圖！\r\n-->\r\n\r\n```python\r\ns1 = input()\r\ns2 = input()\r\nprint(s1 + s2)\r\n```\r\n\r\n## 錯誤訊息\r\n\r\n<!-- 若有錯誤訊息請提供截圖，若無則請留空。 -->\r\n\r\n## 問題描述\r\n\r\n<!-- 請盡量完整地敘述你的問題。 -->\r\n我的input函數出來的數並非預設的字串，而是變成實數\r\n比如說輸入5和2，出來的並非是52而是7。\r\n'}},
#   'public': True,
#   'created_at': '2020-03-15T09:47:57Z',
#   'org': {'id': 52945582,
#    'login': 'coding-coworking-club',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/coding-coworking-club',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52945582?'}}]

# %% [markdown]
# ## 其它用法

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.23.0',
#   'X-Amzn-Trace-Id': 'Root=1-5e6dfb02-9fe1df5486e67dfc38bc8c58'},
#  'origin': '61.231.51.190',
#  'url': 'http://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.19.1'},
#  'json': None,
#  'origin': '123.195.194.127, 123.195.194.127',
#  'url': 'https://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
