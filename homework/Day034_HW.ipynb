# %% [markdown]
# # 反爬：代理伺服器/IP
#
# * 了解「IP 黑/白名單」的反爬蟲機制
# * 「IP 黑/白名單」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 目前程式中的 proxy_ips 是手動輸入的，請根據 https://free-proxy-list.net/ 寫一個可自動化抓取可用 Proxy 的 proxy_ips。

# %%
from bs4 import BeautifulSoup
import requests
import random

proxy_ips = list()

res = requests.get('https://free-proxy-list.net')
#print(res.text)
soup = BeautifulSoup(res.text, 'html.parser')
trs=soup.find_all('tr')
for tr in trs:
    #print("\n\n"+str(tr)+"\n\n")
    tds=tr.find_all('td')
    i=0
    iptd=None
    porttd=None
    for td in tds:
        i+=1
        if i == 1:
            iptd=td
        elif i == 2:
            porttd=td
    if not iptd is None and re.match(r'^(([0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\.){3}([0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])$',iptd.getText()):
        proxy_ips.append('http://'+iptd.getText()+":"+porttd.getText())
proxy_ips
# Out:
# ['http://3.216.55.189:25201',
#  'http://216.198.188.26:51068',
#  'http://36.74.180.50:3128',
#  'http://187.115.76.17:32589',
#  'http://45.167.172.78:45300',
#  'http://36.89.182.211:45795',
#  'http://202.75.97.82:47009',
#  'http://103.142.68.38:8080',
#  'http://185.59.247.69:41258',
#  'http://117.54.13.174:34190',
#  'http://122.248.45.35:53281',
#  'http://173.217.255.36:33351',
#  'http://197.216.2.18:8080',
#  'http://103.21.163.86:35101',
#  'http://89.42.133.58:8080',
#  'http://201.55.164.229:3128',
#  'http://94.230.155.57:38786',
#  'http://201.132.92.130:52800',
#  'http://125.26.165.17:39947',
#  'http://202.51.110.158:32247',
#  'http://2.178.145.212:8080',
#  'http://103.141.108.161:3127',
#  'http://89.109.239.183:47837',
#  'http://200.73.128.5:8080',
#  'http://203.202.254.206:32938',
#  'http://1.10.188.203:45476',
#  'http://169.239.45.37:8080',
#  'http://182.16.166.86:47200',
#  'http://195.214.222.75:8080',
#  'http://36.89.182.153:36152',
# ...

# %%
proxy_ips=['http://3.216.55.189:25201']
for i in range(10):
    ip = random.choice(proxy_ips)
    print('Use', ip)

    resp = requests.get('http://ip.filefab.com/index.php',
                    proxies={'http': ip, 'https': ip}, timeout=10)
    soup = BeautifulSoup(resp.text, 'html5lib')
    print(soup.find('h1', id='ipd').text.strip())
# Out:
# Use http://3.216.55.189:25201
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     156             conn = connection.create_connection(
# --> 157                 (self._dns_host, self.port), self.timeout, **extra_kw
#     158             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# ConnectionRefusedError: [WinError 10061] 無法連線，因為目標電腦拒絕連線。
#
# ...
