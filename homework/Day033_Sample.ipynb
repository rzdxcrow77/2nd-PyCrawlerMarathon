# %% [markdown]
# # 反爬：登入授權模擬
#
# * 了解「登入權限機制」的反爬蟲機制
# * 「登入權限機制」反爬蟲的因應策略

# %% [markdown]
# ## 未授權前存取

# %%
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html', verify = False)
soup = BeautifulSoup(res.text, 'html.parser')
print(soup.text)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 本網站已依網站內容分級規定處理
# 警告︰您即將進入之看板內容需滿十八歲方可瀏覽。
# 若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。
#
#
#
#
#
#
# 我同意，我已年滿十八歲進入
#
#
# 未滿十八歲或不同意本條款離開
#
#
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');

# %% [markdown]
# ## 模仿授權機制

# %% [markdown]
# ### 方法一：先送登入，再送請求

# %%
rs = requests.session()
payload={
    'from':'/bbs/Gossiping/index.html',
    'yes': 'yes'
}
res = rs.post('https://www.ptt.cc/ask/over18',verify = False, data = payload)
res = rs.get('https://www.ptt.cc/bbs/Gossiping/index.html',verify = False)
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
# 4
#
# [問卦] ㄟ！被貓貓幸臨後院了怎麼款待？☺
#
#
# js52666
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 js52666 的文章
#
#
#  4/09
#
#
#
#
# 1
#
# [問卦] 武廢證明484不能伍茼
#
#
# anonymitet
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 anonymitet 的文章
#
#
#  4/09
#
#
#
#
#
#
# Re: [政治] 艦船開假訊號偽冒遼寧艦 國防部快速打擊
#
#
# Zeelandia
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Zeelandia 的文章
#
#
#  4/09
#
#
#
#
#
#
#
# 				(本文已被刪除) [ORK]
#
#
#
# -
#
#
#  4/09
#
#
#
#
# 5
#
# [新聞] 酒店停業？台中兩家知名店 非登記「酒店
#
#
# pttpepe
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 pttpepe 的文章
#
#
#  4/09
#
#
#
#
#
#
# [問卦] 韋禮安已經路人到要蹭分貓油土伯了嗎？
#
#
# xzcb2008
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 xzcb2008 的文章
#
#
#  4/09
#
#
#
#
# 1
#
# [問卦] 很難起床也是感染的症狀之一？？？
#
#
# brucesuperQ
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 brucesuperQ 的文章
#
#
#  4/09
#
#
#
#
#
#
# [新聞] 「不幫你送 你下來我移送」 鄭文燦：社
#
#
# medama
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 medama 的文章
#
#
#  4/09
#
#
#
#
# 1
#
# [新聞] 批市府像土匪！夾娃娃機充滿18禁挨罰2萬
#
#
# leon105
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 leon105 的文章
#
#
#  4/09
#
#
#
#
#
#
# [問卦] 有沒有在公家機關被排擠的八卦嗎?
#
#
# lalalamb
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 lalalamb 的文章
#
#
#  4/09
#
#
#
#
#
#
#
# [公告] 八卦板板規(2020.03.21)
#
#
# DreamYeh
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 DreamYeh 的文章
#
#
#  3/21
# !
#
#
#
# 爆
#
# [協尋]  3/25  16點寶山路往食品路車禍影像
#
#
# funnyemma
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 funnyemma 的文章
#
#
#  3/26
#
#
#
#
# 6
#
# [公告] 一天只能一篇[政治]或[新聞]的新聞 水桶
#
#
# seabox
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 seabox 的文章
#
#
#  4/09
# M
#
#
#
# 12
#
# [公告] 四月份置底閒聊文
#
#
# Kay731
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Kay731 的文章
#
#
#  4/08
# M
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %% [markdown]
# ### 方法二：在請求中帶入 cookie

# %%
res = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html',verify = False, cookies={'over18': '1'})
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
# 7
#
# [問卦] ㄟ！被貓貓幸臨後院了怎麼款待？☺
#
#
# js52666
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 js52666 的文章
#
#
#  4/09
#
#
#
#
# 1
#
# [問卦] 武廢證明484不能伍茼
#
#
# anonymitet
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 anonymitet 的文章
#
#
#  4/09
#
#
#
#
#
#
# Re: [政治] 艦船開假訊號偽冒遼寧艦 國防部快速打擊
#
#
# Zeelandia
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Zeelandia 的文章
#
#
#  4/09
#
#
#
#
#
#
#
# 				(本文已被刪除) [ORK]
#
#
#
# -
#
#
#  4/09
#
#
#
#
# 6
#
# [新聞] 酒店停業？台中兩家知名店 非登記「酒店
#
#
# pttpepe
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 pttpepe 的文章
#
#
#  4/09
#
#
#
#
# 1
#
# [問卦] 韋禮安已經路人到要蹭分貓油土伯了嗎？
#
#
# xzcb2008
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 xzcb2008 的文章
#
#
#  4/09
#
#
#
#
# 2
#
# [問卦] 很難起床也是感染的症狀之一？？？
#
#
# brucesuperQ
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 brucesuperQ 的文章
#
#
#  4/09
#
#
#
#
# 1
#
# [新聞] 「不幫你送 你下來我移送」 鄭文燦：社
#
#
# medama
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 medama 的文章
#
#
#  4/09
#
#
#
#
# 1
#
# [新聞] 批市府像土匪！夾娃娃機充滿18禁挨罰2萬
#
#
# leon105
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 leon105 的文章
#
#
#  4/09
#
#
#
#
#
#
# [問卦] 有沒有在公家機關被排擠的八卦嗎?
#
#
# lalalamb
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 lalalamb 的文章
#
#
#  4/09
#
#
#
#
# 1
#
# [問卦] 版上各位學長請進!!
#
#
# mHRUed
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 mHRUed 的文章
#
#
#  4/09
#
#
#
#
#
#
# [政治] 蔡依林抗疫歌惹議 館長狂酸：敢講中華民
#
#
# xianfen
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 xianfen 的文章
#
#
#  4/09
#
#
#
#
#
#
# [新聞] 高市府突檢金芭黎、大帝國舞廳 舞小姐忙
#
#
# pigoilstand
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 pigoilstand 的文章
#
#
#  4/09
#
#
#
#
#
#
#
# [公告] 八卦板板規(2020.03.21)
#
#
# DreamYeh
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 DreamYeh 的文章
#
#
#  3/21
# !
#
#
#
# 爆
#
# [協尋]  3/25  16點寶山路往食品路車禍影像
#
#
# funnyemma
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 funnyemma 的文章
#
#
#  3/26
#
#
#
#
# 6
#
# [公告] 一天只能一篇[政治]或[新聞]的新聞 水桶
#
#
# seabox
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 seabox 的文章
#
#
#  4/09
# M
#
#
#
# 12
#
# [公告] 四月份置底閒聊文
#
#
# Kay731
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Kay731 的文章
#
#
#  4/08
# M
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %% [markdown]
# ## 作業目標
#
# * 找一個需要登入的網站試試看，並說明思考流程
# （如果不知道要用哪個網站的話，可以試試看 https://github.com/new 網址，未登入時會被導向登入頁）
